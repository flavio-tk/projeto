# %%
# Programa que faz a leitura do arquivo historico_mensal.csv na camada TRUSTED do Data Lake e 
# utliza dados médios mensais (1981 até 2022) para realizar a previsão de radiação com o modelo de redes neurais 

# Nome do programa: previsor_energia_solar
# Dado de entrada: Arquivo historico_mensal.csv com dados tratados de média mensal de radiação solar entre 1985 e 2022
# Dados de saída: Previsão da radiação solar entre 2015 e 2022


# Importação de bibliotecas
# %matplotlib inline

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 

from sklearn.preprocessing import MinMaxScaler
from keras.layers import SimpleRNN
from keras.layers import LSTM
from keras.models import Sequential
from numpy.random import seed
from tensorflow.keras.utils import set_random_seed

# %%
# 
seed(42)
set_random_seed(42)

plt.rcParams['figure.figsize'] = 16,4

# %%
#Endereço base de leitura do Data Lake
# endereco_base = "/content/sample_data/"
endereco_base = "GOLD/"

# Nome do arquivo de entrada
nome_arquivo = "historico_mensal.csv"

# Endereço do arquivo de entrada
arquivo_leitura = endereco_base + nome_arquivo

# %%
# Leitura do arquivo de entrada
df = pd.read_csv(arquivo_leitura, sep=";")

df.head(10)
# Out:
#    Unnamed: 0   timestamp  ALLSKY_SFC_LW_DWN
# 0          60  1986-03-01         390.777419
# 1          61  1986-03-01         371.800000
# 2          62  1986-03-01         377.367742
# 3          63  1986-03-01         368.120000
# 4          64  1986-03-01         357.258065
# 5          65  1986-03-01         338.640000
# 6          66  1986-03-01         328.735484
# 7          67  1986-03-01         349.848387
# 8          68  1986-03-01         353.806667
# 9          69  1986-03-01         354.603226

# %%
# Reordenar as colunas
df = df.reindex(columns=['timestamp', 'ALLSKY_SFC_LW_DWN'])

df.head(10)
# Out:
#     timestamp  ALLSKY_SFC_LW_DWN
# 0  1986-03-01         390.777419
# 1  1986-03-01         371.800000
# 2  1986-03-01         377.367742
# 3  1986-03-01         368.120000
# 4  1986-03-01         357.258065
# 5  1986-03-01         338.640000
# 6  1986-03-01         328.735484
# 7  1986-03-01         349.848387
# 8  1986-03-01         353.806667
# 9  1986-03-01         354.603226

# %%
# Definação da data de divisão entre os conjuntos de treinamento e teste
SPLIT_DATE = '2015-01-01'

# Definação do espaço da janela de tempo que será utilizado no previsor com redes neurais
WINDOW_SIZE = 7 # Janeja de 7 meses

# %%
# Divisão do dataframe dos conjuntos de treino e teste com base na variável SPLIT_DATE
df_train = df[df.timestamp < SPLIT_DATE].copy()
df_test = df[df.timestamp >= SPLIT_DATE].copy()

# %%
# Reescalar as variaveis de entrada da rede neural para ficarem entre -1 e 1
scaler = MinMaxScaler()
df_train['ALLSKY_SFC_LW_DWN'] = scaler.fit_transform(df_train['ALLSKY_SFC_LW_DWN'].values.reshape(-1, 1))
df_test['ALLSKY_SFC_LW_DWN'] = scaler.transform(df_test['ALLSKY_SFC_LW_DWN'].values.reshape(-1, 1))

# %%
 def gen_rnn_inputs(df, window_size):
    X, y = [], []
    averages = df['ALLSKY_SFC_LW_DWN'].values
    
    for i in range(window_size, len(df)):
        X.append(averages[i-window_size: i])
        y.append(averages[i])
        
    return np.array(X), np.array(y)

# %%
# Divisão dos valores de X e y para os conjuntos de treino e teste com base na variável SPLIT_DATE e WINDOW_SIZE
X_train, y_train = gen_rnn_inputs(df_train, WINDOW_SIZE)      
X_test, y_test = gen_rnn_inputs(df_test, WINDOW_SIZE)

# %%
# Criação da estrutura do Modelo de Machine Learning com redes neurais
model = Sequential()
model.add(SimpleRNN(1, return_sequences=False, input_shape=(WINDOW_SIZE, 1)))

# Definação da função de erro
model.compile(optimizer='adam',loss='mean_squared_error')

# Apresenta o resumo do modelo de redes neurais que será utilizado
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  simple_rnn_1 (SimpleRNN)    (None, 1)                 3
#
# =================================================================
# Total params: 3
# Trainable params: 3
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Treinamento da rede neural
model.fit(np.expand_dims(X_train, axis=-1), y_train, epochs=100, batch_size=8, verbose=2)
# Out:
# Epoch 1/100
# 43/43 - 2s - loss: 0.1426 - 2s/epoch - 37ms/step
# Epoch 2/100
# 43/43 - 0s - loss: 0.1225 - 162ms/epoch - 4ms/step
# Epoch 3/100
# 43/43 - 0s - loss: 0.0990 - 160ms/epoch - 4ms/step
# Epoch 4/100
# 43/43 - 0s - loss: 0.0747 - 145ms/epoch - 3ms/step
# Epoch 5/100
# 43/43 - 0s - loss: 0.0568 - 145ms/epoch - 3ms/step
# Epoch 6/100
# 43/43 - 0s - loss: 0.0494 - 157ms/epoch - 4ms/step
# Epoch 7/100
# 43/43 - 0s - loss: 0.0473 - 140ms/epoch - 3ms/step
# Epoch 8/100
# 43/43 - 0s - loss: 0.0462 - 101ms/epoch - 2ms/step
# Epoch 9/100
# 43/43 - 0s - loss: 0.0451 - 90ms/epoch - 2ms/step
# Epoch 10/100
# 43/43 - 0s - loss: 0.0442 - 96ms/epoch - 2ms/step
# Epoch 11/100
# 43/43 - 0s - loss: 0.0432 - 97ms/epoch - 2ms/step
# Epoch 12/100
# 43/43 - 0s - loss: 0.0424 - 86ms/epoch - 2ms/step
# Epoch 13/100
# 43/43 - 0s - loss: 0.0415 - 102ms/epoch - 2ms/step
# Epoch 14/100
# 43/43 - 0s - loss: 0.0407 - 104ms/epoch - 2ms/step
# Epoch 15/100
# 43/43 - 0s - loss: 0.0399 - 100ms/epoch - 2ms/step
# Epoch 16/100
# 43/43 - 0s - loss: 0.0391 - 93ms/epoch - 2ms/step
# Epoch 17/100
# 43/43 - 0s - loss: 0.0384 - 101ms/epoch - 2ms/step
# Epoch 18/100
# 43/43 - 0s - loss: 0.0377 - 90ms/epoch - 2ms/step
# Epoch 19/100
# 43/43 - 0s - loss: 0.0371 - 94ms/epoch - 2ms/step
# Epoch 20/100
# 43/43 - 0s - loss: 0.0365 - 106ms/epoch - 2ms/step
# Epoch 21/100
# 43/43 - 0s - loss: 0.0359 - 94ms/epoch - 2ms/step
# Epoch 22/100
# 43/43 - 0s - loss: 0.0353 - 87ms/epoch - 2ms/step
# Epoch 23/100
# 43/43 - 0s - loss: 0.0348 - 88ms/epoch - 2ms/step
# Epoch 24/100
# 43/43 - 0s - loss: 0.0343 - 112ms/epoch - 3ms/step
# Epoch 25/100
# 43/43 - 0s - loss: 0.0338 - 95ms/epoch - 2ms/step
# Epoch 26/100
# 43/43 - 0s - loss: 0.0333 - 110ms/epoch - 3ms/step
# Epoch 27/100
# 43/43 - 0s - loss: 0.0329 - 94ms/epoch - 2ms/step
# Epoch 28/100
# 43/43 - 0s - loss: 0.0326 - 99ms/epoch - 2ms/step
# Epoch 29/100
# 43/43 - 0s - loss: 0.0321 - 109ms/epoch - 3ms/step
# Epoch 30/100
# 43/43 - 0s - loss: 0.0317 - 101ms/epoch - 2ms/step
# Epoch 31/100
# 43/43 - 0s - loss: 0.0314 - 86ms/epoch - 2ms/step
# Epoch 32/100
# 43/43 - 0s - loss: 0.0310 - 100ms/epoch - 2ms/step
# Epoch 33/100
# 43/43 - 0s - loss: 0.0307 - 92ms/epoch - 2ms/step
# Epoch 34/100
# 43/43 - 0s - loss: 0.0304 - 96ms/epoch - 2ms/step
# Epoch 35/100
# 43/43 - 0s - loss: 0.0303 - 95ms/epoch - 2ms/step
# Epoch 36/100
# 43/43 - 0s - loss: 0.0299 - 104ms/epoch - 2ms/step
# Epoch 37/100
# 43/43 - 0s - loss: 0.0296 - 94ms/epoch - 2ms/step
# Epoch 38/100
# 43/43 - 0s - loss: 0.0293 - 100ms/epoch - 2ms/step
# Epoch 39/100
# 43/43 - 0s - loss: 0.0291 - 99ms/epoch - 2ms/step
# Epoch 40/100
# 43/43 - 0s - loss: 0.0289 - 104ms/epoch - 2ms/step
# Epoch 41/100
# 43/43 - 0s - loss: 0.0287 - 105ms/epoch - 2ms/step
# Epoch 42/100
# 43/43 - 0s - loss: 0.0285 - 100ms/epoch - 2ms/step
# Epoch 43/100
# 43/43 - 0s - loss: 0.0283 - 120ms/epoch - 3ms/step
# Epoch 44/100
# 43/43 - 0s - loss: 0.0280 - 112ms/epoch - 3ms/step
# Epoch 45/100
# 43/43 - 0s - loss: 0.0279 - 103ms/epoch - 2ms/step
# Epoch 46/100
# 43/43 - 0s - loss: 0.0277 - 90ms/epoch - 2ms/step
# Epoch 47/100
# 43/43 - 0s - loss: 0.0275 - 101ms/epoch - 2ms/step
# Epoch 48/100
# 43/43 - 0s - loss: 0.0274 - 100ms/epoch - 2ms/step
# Epoch 49/100
# 43/43 - 0s - loss: 0.0272 - 103ms/epoch - 2ms/step
# Epoch 50/100
# 43/43 - 0s - loss: 0.0270 - 99ms/epoch - 2ms/step
# Epoch 51/100
# 43/43 - 0s - loss: 0.0269 - 95ms/epoch - 2ms/step
# Epoch 52/100
# 43/43 - 0s - loss: 0.0267 - 108ms/epoch - 3ms/step
# Epoch 53/100
# 43/43 - 0s - loss: 0.0266 - 118ms/epoch - 3ms/step
# Epoch 54/100
# 43/43 - 0s - loss: 0.0265 - 97ms/epoch - 2ms/step
# Epoch 55/100
# 43/43 - 0s - loss: 0.0264 - 90ms/epoch - 2ms/step
# Epoch 56/100
# 43/43 - 0s - loss: 0.0263 - 92ms/epoch - 2ms/step
# Epoch 57/100
# 43/43 - 0s - loss: 0.0261 - 90ms/epoch - 2ms/step
# Epoch 58/100
# 43/43 - 0s - loss: 0.0260 - 102ms/epoch - 2ms/step
# Epoch 59/100
# 43/43 - 0s - loss: 0.0259 - 101ms/epoch - 2ms/step
# Epoch 60/100
# 43/43 - 0s - loss: 0.0258 - 96ms/epoch - 2ms/step
# Epoch 61/100
# 43/43 - 0s - loss: 0.0257 - 101ms/epoch - 2ms/step
# Epoch 62/100
# 43/43 - 0s - loss: 0.0256 - 96ms/epoch - 2ms/step
# Epoch 63/100
# 43/43 - 0s - loss: 0.0255 - 104ms/epoch - 2ms/step
# Epoch 64/100
# 43/43 - 0s - loss: 0.0254 - 87ms/epoch - 2ms/step
# Epoch 65/100
# 43/43 - 0s - loss: 0.0253 - 105ms/epoch - 2ms/step
# Epoch 66/100
# 43/43 - 0s - loss: 0.0252 - 96ms/epoch - 2ms/step
# Epoch 67/100
# 43/43 - 0s - loss: 0.0251 - 100ms/epoch - 2ms/step
# Epoch 68/100
# 43/43 - 0s - loss: 0.0251 - 95ms/epoch - 2ms/step
# Epoch 69/100
# 43/43 - 0s - loss: 0.0250 - 88ms/epoch - 2ms/step
# Epoch 70/100
# 43/43 - 0s - loss: 0.0249 - 98ms/epoch - 2ms/step
# Epoch 71/100
# 43/43 - 0s - loss: 0.0248 - 92ms/epoch - 2ms/step
# Epoch 72/100
# 43/43 - 0s - loss: 0.0247 - 89ms/epoch - 2ms/step
# Epoch 73/100
# 43/43 - 0s - loss: 0.0246 - 121ms/epoch - 3ms/step
# Epoch 74/100
# 43/43 - 0s - loss: 0.0246 - 93ms/epoch - 2ms/step
# Epoch 75/100
# 43/43 - 0s - loss: 0.0245 - 97ms/epoch - 2ms/step
# Epoch 76/100
# 43/43 - 0s - loss: 0.0244 - 95ms/epoch - 2ms/step
# Epoch 77/100
# 43/43 - 0s - loss: 0.0244 - 101ms/epoch - 2ms/step
# Epoch 78/100
# 43/43 - 0s - loss: 0.0243 - 95ms/epoch - 2ms/step
# Epoch 79/100
# 43/43 - 0s - loss: 0.0242 - 98ms/epoch - 2ms/step
# Epoch 80/100
# 43/43 - 0s - loss: 0.0242 - 91ms/epoch - 2ms/step
# Epoch 81/100
# 43/43 - 0s - loss: 0.0241 - 100ms/epoch - 2ms/step
# Epoch 82/100
# 43/43 - 0s - loss: 0.0240 - 100ms/epoch - 2ms/step
# Epoch 83/100
# 43/43 - 0s - loss: 0.0240 - 122ms/epoch - 3ms/step
# Epoch 84/100
# 43/43 - 0s - loss: 0.0239 - 101ms/epoch - 2ms/step
# Epoch 85/100
# 43/43 - 0s - loss: 0.0239 - 101ms/epoch - 2ms/step
# Epoch 86/100
# 43/43 - 0s - loss: 0.0238 - 97ms/epoch - 2ms/step
# Epoch 87/100
# 43/43 - 0s - loss: 0.0238 - 104ms/epoch - 2ms/step
# Epoch 88/100
# 43/43 - 0s - loss: 0.0237 - 109ms/epoch - 3ms/step
# Epoch 89/100
# 43/43 - 0s - loss: 0.0237 - 88ms/epoch - 2ms/step
# Epoch 90/100
# 43/43 - 0s - loss: 0.0236 - 87ms/epoch - 2ms/step
# Epoch 91/100
# 43/43 - 0s - loss: 0.0236 - 91ms/epoch - 2ms/step
# Epoch 92/100
# 43/43 - 0s - loss: 0.0235 - 102ms/epoch - 2ms/step
# Epoch 93/100
# 43/43 - 0s - loss: 0.0235 - 107ms/epoch - 2ms/step
# Epoch 94/100
# 43/43 - 0s - loss: 0.0234 - 99ms/epoch - 2ms/step
# Epoch 95/100
# 43/43 - 0s - loss: 0.0234 - 91ms/epoch - 2ms/step
# Epoch 96/100
# 43/43 - 0s - loss: 0.0234 - 96ms/epoch - 2ms/step
# Epoch 97/100
# 43/43 - 0s - loss: 0.0233 - 91ms/epoch - 2ms/step
# Epoch 98/100
# 43/43 - 0s - loss: 0.0233 - 95ms/epoch - 2ms/step
# Epoch 99/100
# 43/43 - 0s - loss: 0.0233 - 89ms/epoch - 2ms/step
# Epoch 100/100
# 43/43 - 0s - loss: 0.0232 - 88ms/epoch - 2ms/step

# %%
# Previsão de dados do conjunto teste com base na rede treinada
y_pred = model.predict(np.expand_dims(X_test, axis=-1))
# Out:
# 3/3 [==============================] - 0s 4ms/step

# %%
# Conversão para os valores originais das variveis reescaladas (-1 até 1)
df_test_preds = df_test.copy()
df_test_preds['ALLSKY_SFC_LW_DWN'] = np.zeros(WINDOW_SIZE).tolist() + scaler.inverse_transform(y_test.reshape(-1,1)).squeeze().tolist()
df_test_preds['Pred'] = np.zeros(WINDOW_SIZE).tolist() + scaler.inverse_transform(y_pred.reshape(-1,1)).squeeze().tolist()

# %%
# Plote dos dados da previsão da rede neural para o conjunto de teste
df_test_preds.plot(legend=True)

plt.xlabel('Meses')
plt.ylabel('Radiação horizontal (kWh/m2)')
plt.title('Radiação horizontal na cidade de São Paulo')

# Rotacionar os rótulos do eixo x em 45 graus
plt.xticks(rotation=90)

plt.show()

# %%
# Plotar o gráfico do conjunto de dados originais

df.plot(legend=True)
df = df.set_index('timestamp')
plt.xlabel('Meses')
plt.ylabel('Radiação horizontal (kWh/m2)')
plt.title('Radiação horizontal na cidade de São Paulo')

# Rotacionar os rótulos do eixo x em 45 graus
plt.xticks(rotation=90)

# Definir os ticks do eixo x a cada 12 dados
xticks = np.arange(0, len(df), 120)
plt.xticks(xticks)

plt.show()
